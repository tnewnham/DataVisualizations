# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfInsurance = pd.read_csv('./car insurance premiums.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            51 non-null     object
#  1   fatal_collisions                 51 non-null     float64
#  2   fatal_collisions_speeding        51 non-null     int64
#  3   fatal_collisions_alc             51 non-null     int64
#  4   fatal_collisions_not_distracted  51 non-null     int64
#  5   fatal_collisions_no_hist         51 non-null     int64
#  6   premiums                         51 non-null     float64
#  7   insurance_losses                 51 non-null     float64
#  8   Region                           51 non-null     object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 3.7+ KB

# %%
sns.pairplot(data=dfInsurance,
             vars=["insurance_losses", "premiums"],
             kind='reg',
             palette='BrBG',
             diag_kind = 'kde',
             hue='Region')

# %%
sns.pairplot(data=dfInsurance,
        vars=["fatal_collisions", "premiums"],
        kind='scatter',
        hue='Region',
        palette='RdBu',
        diag_kws={'alpha':.5})

# %%
dfBikes = pd.read_csv('./washintonDCbikeShare.csv')

# %%
sns.set_style("whitegrid")
g = sns.JointGrid(x="hum",
            y="total_rentals",
            data=dfBikes,
            xlim=(0.1, 1.0))
g.plot(sns.regplot, sns.distplot)

# %%
g = (sns.jointplot(x="temp",
             y="registered",
             kind='scatter',
             data=dfBikes,
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.kdeplot))

# %%
dfTuition = pd.read_csv('./2018CollegeScorecardTuition.csv')

# %%
sns.lmplot(data=dfTuition,
        x='SAT_AVG_ALL',
        y='Tuition',
        col="Ownership",
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors'],
        hue='WOMENONLY',
        col_order=['Public', 'Private non-profit' ])
